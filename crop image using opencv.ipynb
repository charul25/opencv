# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ## load sample image

# %%
image = cv2.imread("C:\images\dog.jpg")

# %% [markdown]
# ## display loaded image

# %%
plt.title('Original Image')
plt.imshow(image)

# %% [markdown]
# ## crop image

# %%
cropped = image[0:175,100:250]

# %% [markdown]
# ## display cropped image

# %%
plt.title('cropped Image')
plt.imshow(cropped)
