# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread("C:\images\dog.jpg",1)
plt.title('original')
plt.imshow(image)

# %%
resized = cv2.resize(image,(300,300))
plt.title('resized image')
plt.imshow(resized)
